# %%
#Refine FFTDock poses via minimization in explicit protein
#Inputs:
    #cofactor/pdb_with_fad/tropb.pdb
    #dock/ligands/2.pdb
    #dock/ligands/2.str #CGenFF stream file
    #dock/poses/tropb_2_fftdock
    #toppar
#Outputs:
    #dock/poses/tropb_2_prot
    #dock/scores/tropb_2_prot.csv

# %%
import os 
import re
import pandas as pd
import numpy as np
os.environ['CHARMM_LIB_DIR'] = "/home/azamh/charmm-dev/lib"
os.chdir('/home/azamh/demo/seq_struct_func/dock')

# These are a subset of the pycharmm modules that were installed when
# pycharmm was installed in your python environment
import pycharmm
import pycharmm.generate as gen
import pycharmm.ic as ic
import pycharmm.coor as coor
import pycharmm.energy as energy
import pycharmm.dynamics as dyn
import pycharmm.nbonds as nbonds
import pycharmm.minimize as minimize
import pycharmm.crystal as crystal
import pycharmm.image as image
import pycharmm.psf as psf
import pycharmm.read as read
import pycharmm.write as write
import pycharmm.settings as settings
import pycharmm.cons_harm as cons_harm
import pycharmm.cons_fix as cons_fix
import pycharmm.select as select
import pycharmm.shake as shake
import pycharmm.settings as settings
import pycharmm.grid as grid
import pycharmm.charmm_file as charmm_file
from pycharmm.select_atoms import SelectAtoms
from pycharmm.lingo import charmm_script

from pycharmm.lib import charmm as libcharmm
# Out:
# [gollum153][[12515,1],0][../../../../../openmpi-3.1.2/opal/mca/btl/openib/btl_openib_component.c:1671:init_one_device] error obtaining device attributes for mlx5_0 errno says Protocol not supported
# --------------------------------------------------------------------------
# WARNING: There was an error initializing an OpenFabrics device.
#
#   Local host:   gollum153
#   Local device: mlx5_0
# --------------------------------------------------------------------------

# %%
#Arguments
protein = 'tropb'
ligand = '2'
toppardir = '../toppar'
liganddir = './ligands'
proteindir = '../cofactor/pdb_with_fad'
fftdockdir = f'poses/{protein}_{ligand}_fftdock'
dockdir = f'poses/{protein}_{ligand}_prot'
os.makedirs(dockdir, exist_ok=True)

# %%
## Read in the topology and parameter file 
settings.set_bomb_level(-1)
read.rtf(os.path.join(toppardir, 'top_all36_prot.rtf'))
read.rtf(os.path.join(toppardir,'top_all36_cgenff.rtf'), append = True)
read.rtf(os.path.join(toppardir,'probes.rtf'), append = True)
read.prm(os.path.join(toppardir, 'par_all36m_prot.prm'), flex = True)
read.prm(os.path.join(toppardir, 'par_all36_cgenff.prm'), append = True, flex = True)
read.prm(os.path.join(toppardir, 'probes.prm'), append = True, flex = True)
settings.set_bomb_level(0)
charmm_script(f'stream {os.path.join(liganddir, ligand)}.str')
charmm_script(f'stream {os.path.join(toppardir, "st2_fadh.str")}')
# Out:
#
#  CHARMM>     read rtf card -
#  CHARMM>     name ../toppar/top_all36_prot.rtf
#  VOPEN> Attempting to open::../toppar/top_all36_prot.rtf::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> *>>>>>>>>CHARMM36 ALL-HYDROGEN TOPOLOGY FILE FOR PROTEINS <<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> MAY 2011 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read rtf card -
#  CHARMM>     name ../toppar/top_all36_cgenff.rtf -
#  CHARMM>     append
#  VOPEN> Attempting to open::../toppar/top_all36_cgenff.rtf::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *          CGENFF: TOPOLOGY FOR THE CHARMM GENERAL FORCE FIELD V. 4.6          *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *
#
#  DRUDES PARTICLES WILL BE GENERATED AUTOMATICALLY FOR ALL ATOMS WITH NON-ZERO ALPHA
#  Thole-type dipole screening, Slater-Delta shape {S(u) = 1 - (1+u/2)*exp(-u)}, default radius =  1.300000
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read rtf card -
#  CHARMM>     name ../toppar/probes.rtf -
#  CHARMM>     append
#  VOPEN> Attempting to open::../toppar/probes.rtf::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> * ...
#  TITLE> *
#
#       ***** LEVEL  1 WARNING FROM <rtfrdr> *****
#       ***** No AUTOgen defaults specified in appended RTF. Potential conflict with prior RTF autogen options. Check.
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name ../toppar/par_all36m_prot.prm -
#  CHARMM>     flex
#  VOPEN> Attempting to open::../toppar/par_all36m_prot.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> *>>>> CHARMM36 ALL-HYDROGEN PARAMETER FILE FOR PROTEINS <<<<<<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> JAN. 2016 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name ../toppar/par_all36_cgenff.prm -
#  CHARMM>     append -
#  CHARMM>     flex
#  VOPEN> Attempting to open::../toppar/par_all36_cgenff.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *         CGENFF: PARAMETERS FOR THE CHARMM GENERAL FORCE FIELD V. 4.6         *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *  2017/8: IF PROTEIN, NUCLEIC ACID AND CARBOHYDRATE TOPOLOGY AND PARAMETER FILES
#  TITLE> *  ARE NOT READ PRIOR TO THE CGENFF FILES "WARNING: ATOMS IN NBFIX ' errors will
#  TITLE> *  BE ENCOUNTERED.  THESE CAN BE PASSED BY SETTING BOMLEV ( -2) PRIOR TO READING
#  TITLE> *  THIS FILE. IN ADDITION, WHEN GENERATING AROMATIC HALOGENS (CL, BR, I) WITH
#  TITLE> *  PRE C41B/C42A VERSIONS OF CHARMM "MISSING PARAMETER" ERRORS WILL BE
#  TITLE> *  ENCOUNTERED THAT ALSO REQUIRE SETTING BOMLEV ( -2).
#  TITLE> *
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L CLGR   -3.60000   3.18000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L BRGR   -3.65000   3.33000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  CLGR   -0.40000   3.88000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  BRGR   -0.30000   4.05000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C BRGR   -0.27000   3.52000 DONT EXIST
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name ../toppar/probes.prm -
#  CHARMM>     append -
#  CHARMM>     flex
#  VOPEN> Attempting to open::../toppar/probes.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> * TEST PROBES FOR GRID POTENTIAL SET-UP
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     stream ./ligands/2.str
#  VOPEN> Attempting to open::./ligands/2.str::
#  OPNLGU> Unit 99 opened for READONLY access to ./ligands/2.str
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.3.0
#  RDTITL> * FOR USE WITH CGENFF VERSION 4.3
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.3.0
#  RDTITL> *
#
#       ***** LEVEL  1 WARNING FROM <rtfrdr> *****
#       ***** No AUTOgen defaults specified in appended RTF. Potential conflict with prior RTF autogen options. Check.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.3.0
#  RDTITL> *
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90
#
#
#  CHARMM>     stream ../toppar/st2_fadh.str
#  VOPEN> Attempting to open::../toppar/st2_fadh.str::
#  OPNLGU> Unit 99 opened for READONLY access to ../toppar/st2_fadh.str
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 1.0.0
#  RDTITL> * FOR USE WITH CGENFF VERSION 3.0.1
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 1.0.0
#  RDTITL> *
#
#       ***** LEVEL  1 WARNING FROM <rtfrdr> *****
#       ***** No AUTOgen defaults specified in appended RTF. Potential conflict with prior RTF autogen options. Check.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
# *** WARNING **** residue FAD  already exists (old one deleted)
#
#       ***** LEVEL  1 WARNING FROM <RTFRDR> *****
#       ***** Residue already exists.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#           RESI FAD           -2.000
#  There were   1 warning(s) from RTFRDR.
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 1.0.0
#  RDTITL> *
#  PARRDR> Error: Repeated BOND parameter (   319): CG2O  NG2D is replaced
#  PARRDR> Error: Repeated BOND parameter (   466): CG2R  NG2D is replaced
#  PARRDR> Error: Repeated BOND parameter (   575): CG32  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (   814): NG2D  CG2O  NG2S is replaced
#  PARRDR> Error: Repeated ANGLE parameter (   815): NG2D  CG2O  OG2D is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1012): CG2O  CG2R  CG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1014): CG2O  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1171): CG2R  CG2R  NG2D is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1175): CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1199): NG2D  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1663): CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1759): NG2R  CG32  HGA2 is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2238): CG2O  NG2D  CG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2373): CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2374): CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2394): CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2448): CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1857): NG2S  CG2O  CG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1859): NG2S  CG2O  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1862): OG2D  CG2O  CG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1864): OG2D  CG2O  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2181): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2182): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2181): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2182): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2264): OG2D  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2643): NG2S  CG2O  NG2D  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2644): OG2D  CG2O  NG2D  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2661): NG2D  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2662): NG2D  CG2O  NG2S  HGP1 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2687): OG2D  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3724): NG2R  CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3794): CG2O  CG2R  CG2R  NG2D is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3795): CG2O  CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3804): NG2R  CG2R  CG2R  NG2D is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3805): NG2R  CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3989): CG2O  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4007): CG2R  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4008): CG2R  CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4435): CG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4441): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4442): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4443): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4441): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4442): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4443): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4441): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4442): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4443): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4484): CG2R  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4485): CG2R  CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4493): NG2D  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4496): NG2D  CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5014): CG32  CG31  CG31  OG31 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5032): OG31  CG31  CG31  OG31 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5103): CG31  CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5105): CG31  CG31  CG32  OG30 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5193): OG31  CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5222): HGA1  CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6107): CG31  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6108): CG31  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6112): HGA2  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6114): HGA2  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated IMPH parameter (   161): CG2O  NG2D  NG2S  OG2D is replaced
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90
# 1

# %%
#Build ligand
ligand_pdb = os.path.join(liganddir, f'{ligand}.pdb')
read.sequence_pdb(ligand_pdb)
gen.new_segment(seg_name = "LIGA")
read.pdb(ligand_pdb, resid = True)
# Out:
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name ./ligands/2.pdb
#  VOPEN> Attempting to open::./ligands/2.pdb::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --     1 RESIDUES
#           LIG
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  GENPSF> Segment   1 has been generated. Its identifier is LIGA.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =        1
#          Number of atoms         =       32   Number of groups     =        1
#          Number of bonds         =       32   Number of angles     =       55
#          Number of dihedrals     =       72   Number of impropers  =        2
#          Number of cross-terms   =        0   Number of autogens   =        0
#          Number of HB acceptors  =        0   Number of HB donors  =        0
#          Number of NB exclusions =        0   Total charge =   -1.00000
#  QXFORM> Expanded format used.
#          More than 4 character atom type used.
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name ./ligands/2.pdb -
#  CHARMM>     resid
#  VOPEN> Attempting to open::./ligands/2.pdb::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>

# %%
#Setup nonbonds
my_nbonds = pycharmm.NonBondedScript(
    cutnb=12.0, ctonnb=10.0, ctofnb=10.0,
    eps=0.75,
    cdie=False,
    rdie=True,
    switch=True, vswitch=True)
# Implement these non-bonded parameters by "running" them.
my_nbonds.run()
# Out:
#
#  CHARMM>     nbonds cutnb 12.0 -
#  CHARMM>     ctonnb 10.0 -
#  CHARMM>     ctofnb 10.0 -
#  CHARMM>     eps 0.75 -
#  CHARMM>     rdie -
#  CHARMM>     switch -
#  CHARMM>     vswitch
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    RDIElec  SWITch   VATOm    VSWItch
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB = 10.000 CTOFNB = 10.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  0.750
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  GTNBCT> CUTNB,CTOFNB,CTONNB=      12.0      10.0      10.0
#
#       ***** LEVEL  1 WARNING FROM <GTNBCT> *****
#       ***** CUTNB,CTOFNB,CTONNB are not in correct order.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#  <MAKINB> with mode   5 found     87 exclusions and     69 interactions(1-4)
#  <MAKGRP> found      0 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR      481 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#       409 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         1 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#
#  CHARMM>

# %%
#Minimize ligand in vacuum for initial energy
minimize.run_sd(nstep=1000, tolenr=1e-3, tolgrd=1e-4)
# Out:
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    RDIElec  SWITch   VATOm    VSWItch
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB = 10.000 CTOFNB = 10.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  0.750
#  NBXMOD =      5
#  There are      409 atom  pairs and      156 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  GTNBCT> CUTNB,CTOFNB,CTONNB=      12.0      10.0      10.0
#
#       ***** LEVEL  1 WARNING FROM <GTNBCT> *****
#       ***** CUTNB,CTOFNB,CTONNB are not in correct order.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR      481 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#       409 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         1 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
#
#
#  STEEPD> An energy minimization has been requested.
#
#  NSTEP  =         1000   NPRINT =           10
#  STEP   =    0.0200000   TOLFUN =    0.0010000
#  TOLGRD =    0.0001000   TOLSTP =    0.0000000
#
# MINI MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# MINI INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# MINI EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>        0     -7.47470      0.00000     10.10051      0.02000
# MINI INTERN>        4.66959      4.67354      0.53870      6.98584      0.00167
# MINI EXTERN>       14.39147    -38.73552      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       10    -14.18727      6.71257      1.19976      0.00156
# MINI INTERN>        2.17882      2.98360      0.18155      6.75936      0.02197
# MINI EXTERN>       14.49087    -40.80344      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       20    -14.66436      0.47710      2.29517      0.00167
# MINI INTERN>        2.28086      3.16099      0.21611      6.55699      0.01243
# MINI EXTERN>       14.66040    -41.55214      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  STEEPD> Minimization exiting with function tolerance ( 0.0010000) satisfied.
#
# STPD MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# STPD INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# STPD EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# STPD>       27    -14.88505      0.22068      1.83457      0.00125
# STPD INTERN>        2.27311      3.20308      0.21659      6.46270      0.00994
# STPD EXTERN>       14.65426    -41.70474      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# True

# %%
## Build protein
protein_psf = os.path.join(proteindir, f'{protein}_fad.psf')
protein_pdb = os.path.join(proteindir, f'{protein}_fad.pdb')
read.psf_card(protein_psf, append = True)
read.pdb(protein_pdb, resid = True)
# Out:
#
#  CHARMM>     read psf card -
#  CHARMM>     name ../cofactor/pdb_with_fad/tropb_fad.psf -
#  CHARMM>     append
#  VOPEN> Attempting to open::../cofactor/pdb_with_fad/tropb_fad.psf::
#  MAINIO> Protein structure file being appended from unit  91.
#  psf_read_formatted: Reading PSF in the expanded format.
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:    12/10/22     14:18:36      CREATED BY USER: azamh
#  TITLE>  *
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        3   Number of residues   =      449
#          Number of atoms         =     7072   Number of groups     =     2043
#          Number of bonds         =     7162   Number of angles     =    12887
#          Number of dihedrals     =    18839   Number of impropers  =     1277
#          Number of cross-terms   =      447   Number of autogens   =        0
#          Number of HB acceptors  =      652   Number of HB donors  =      790
#          Number of NB exclusions =        0   Total charge =   -7.00000
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name ../cofactor/pdb_with_fad/tropb_fad.pdb -
#  CHARMM>     resid
#  VOPEN> Attempting to open::../cofactor/pdb_with_fad/tropb_fad.pdb::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>   EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>    DATE:    12/10/22     14:18:51      CREATED BY USER: AZAMH
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>

# %%
#Fix protein and cofactor atoms
cons_fix.setup(selection = ~SelectAtoms(seg_id='LIGA'))
# Out:
# True

# %%
#Get initial energy of system by translating ligand away from protein
charmm_script('coor tranlate xdir 400 ydir 400 zdir 400 select segid LIGA end')
# Out:
# 1
#
#  CHARMM>     coor tranlate xdir 400 ydir 400 zdir 400 select segid LIGA end
#  SELRPN>     32 atoms have been selected out of   7072
#  TRANSLATION VECTOR   400.000000  400.000000  400.000000
#  SELECTED COORDINATES TRANSLATED IN THE MAIN SET.

# %%
#Get initial energy
def get_energy_df(pose_name):
    df = energy.get_energy().set_index('name').drop(columns = 'feature').transpose()
    df.index = [pose_name]
    df.index.name = 'pose'
    df.columns.name = 'term'
    return df
initial_energy_df = get_energy_df('initial')
print(initial_energy_df)
# Out:
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    RDIElec  SWITch   VATOm    VSWItch
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB = 10.000 CTOFNB = 10.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  0.750
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  GTNBCT> CUTNB,CTOFNB,CTONNB=      12.0      10.0      10.0
#
#       ***** LEVEL  1 WARNING FROM <GTNBCT> *****
#       ***** CUTNB,CTOFNB,CTONNB are not in correct order.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#  <MAKINB> with mode   5 found  20049 exclusions and  18468 interactions(1-4)
#  <MAKGRP> found   5960 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  1279721 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       20.12 Angstroms and starts with atom:    6989
#    Please check group boundary definitions.
#
#  General atom nonbond list generation found:
#       409 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         1 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0    -14.88505      0.22068      1.83457
# ENER INTERN>        2.27311      3.20308      0.21659      6.46270      0.00994
# ENER EXTERN>       14.65426    -41.70474      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# term        energy        deltae      grms     bonds    angles     ureyb  \
# pose
# initial -14.885048 -1.278977e-13  1.834568  2.273115  3.203081  0.216589
#
# term     dihedrals  impropers    vdwaals       elec  hbonds  asp  user
# pose
# initial     6.4627   0.009944  14.654264 -41.704742     0.0  0.0   0.0

# %%
#Minimize all fftdock poses
nsave = 500
pose_energy_dfs = [initial_energy_df]

#Hide large output
settings.set_verbosity(0)
settings.set_warn_level(-2)
for i in range(1, nsave + 1):
    print('minimizing fftdock pose', i)
    
    #Read FFTDock pose
    fftdock_pose = os.path.join(fftdockdir, f'{protein}_{ligand}_{i}.crd')
    read.pdb(fftdock_pose, resid=True)
    energy.show()
    
    #Perform minimization in explicit protein
    minimize.run_sd(nstep=50)
    minimize.run_abnr(nstep=1000, tolenr = 1e-3)

    #Get refined energy
    pose_energy_df = get_energy_df(i)
    pose_energy_dfs.append(pose_energy_df)

    #write pdb
    pose_pdb = os.path.join(dockdir, f'{protein}_{ligand}_{i}.pdb')
    write.coor_pdb(pose_pdb, sele = 'segid LIGA end')

settings.set_verbosity(5)
settings.set_warn_level(0)
# Out:
# minimizing fftdock pose 1
# minimizing fftdock pose 2
# minimizing fftdock pose 3
# minimizing fftdock pose 4
# minimizing fftdock pose 5
# minimizing fftdock pose 6
# minimizing fftdock pose 7
# minimizing fftdock pose 8
# minimizing fftdock pose 9
# minimizing fftdock pose 10
# minimizing fftdock pose 11
# minimizing fftdock pose 12
# minimizing fftdock pose 13
# minimizing fftdock pose 14
# minimizing fftdock pose 15
# minimizing fftdock pose 16
# minimizing fftdock pose 17
# minimizing fftdock pose 18
# minimizing fftdock pose 19
# minimizing fftdock pose 20
# minimizing fftdock pose 21
# minimizing fftdock pose 22
# minimizing fftdock pose 23
# minimizing fftdock pose 24
# minimizing fftdock pose 25
# minimizing fftdock pose 26
# minimizing fftdock pose 27
# minimizing fftdock pose 28
# minimizing fftdock pose 29
# minimizing fftdock pose 30
# minimizing fftdock pose 31
# minimizing fftdock pose 32
# minimizing fftdock pose 33
# minimizing fftdock pose 34
# minimizing fftdock pose 35
# minimizing fftdock pose 36
# minimizing fftdock pose 37
# minimizing fftdock pose 38
# minimizing fftdock pose 39
# minimizing fftdock pose 40
# minimizing fftdock pose 41
# minimizing fftdock pose 42
# minimizing fftdock pose 43
# minimizing fftdock pose 44
# minimizing fftdock pose 45
# minimizing fftdock pose 46
# minimizing fftdock pose 47
# minimizing fftdock pose 48
# minimizing fftdock pose 49
# minimizing fftdock pose 50
# minimizing fftdock pose 51
# minimizing fftdock pose 52
# minimizing fftdock pose 53
# minimizing fftdock pose 54
# minimizing fftdock pose 55
# minimizing fftdock pose 56
# minimizing fftdock pose 57
# minimizing fftdock pose 58
# minimizing fftdock pose 59
# minimizing fftdock pose 60
# minimizing fftdock pose 61
# minimizing fftdock pose 62
# minimizing fftdock pose 63
# minimizing fftdock pose 64
# minimizing fftdock pose 65
# minimizing fftdock pose 66
# minimizing fftdock pose 67
# minimizing fftdock pose 68
# minimizing fftdock pose 69
# minimizing fftdock pose 70
# minimizing fftdock pose 71
# minimizing fftdock pose 72
# minimizing fftdock pose 73
# minimizing fftdock pose 74
# minimizing fftdock pose 75
# minimizing fftdock pose 76
# minimizing fftdock pose 77
# minimizing fftdock pose 78
# minimizing fftdock pose 79
# minimizing fftdock pose 80
# minimizing fftdock pose 81
# minimizing fftdock pose 82
# minimizing fftdock pose 83
# minimizing fftdock pose 84
# minimizing fftdock pose 85
# minimizing fftdock pose 86
# minimizing fftdock pose 87
# minimizing fftdock pose 88
# minimizing fftdock pose 89
# minimizing fftdock pose 90
# minimizing fftdock pose 91
# minimizing fftdock pose 92
# minimizing fftdock pose 93
# minimizing fftdock pose 94
# minimizing fftdock pose 95
# minimizing fftdock pose 96
# minimizing fftdock pose 97
# minimizing fftdock pose 98
# minimizing fftdock pose 99
# minimizing fftdock pose 100
# minimizing fftdock pose 101
# minimizing fftdock pose 102
# minimizing fftdock pose 103
# minimizing fftdock pose 104
# minimizing fftdock pose 105
# minimizing fftdock pose 106
# minimizing fftdock pose 107
# minimizing fftdock pose 108
# minimizing fftdock pose 109
# minimizing fftdock pose 110
# minimizing fftdock pose 111
# minimizing fftdock pose 112
# minimizing fftdock pose 113
# minimizing fftdock pose 114
# minimizing fftdock pose 115
# minimizing fftdock pose 116
# minimizing fftdock pose 117
# minimizing fftdock pose 118
# minimizing fftdock pose 119
# minimizing fftdock pose 120
# minimizing fftdock pose 121
# minimizing fftdock pose 122
# minimizing fftdock pose 123
# minimizing fftdock pose 124
# minimizing fftdock pose 125
# minimizing fftdock pose 126
# minimizing fftdock pose 127
# minimizing fftdock pose 128
# minimizing fftdock pose 129
# minimizing fftdock pose 130
# minimizing fftdock pose 131
# minimizing fftdock pose 132
# minimizing fftdock pose 133
# minimizing fftdock pose 134
# minimizing fftdock pose 135
# minimizing fftdock pose 136
# minimizing fftdock pose 137
# minimizing fftdock pose 138
# minimizing fftdock pose 139
# minimizing fftdock pose 140
# minimizing fftdock pose 141
# minimizing fftdock pose 142
# minimizing fftdock pose 143
# minimizing fftdock pose 144
# minimizing fftdock pose 145
# minimizing fftdock pose 146
# minimizing fftdock pose 147
# minimizing fftdock pose 148
# minimizing fftdock pose 149
# minimizing fftdock pose 150
# minimizing fftdock pose 151
# minimizing fftdock pose 152
# minimizing fftdock pose 153
# minimizing fftdock pose 154
# minimizing fftdock pose 155
# minimizing fftdock pose 156
# minimizing fftdock pose 157
# minimizing fftdock pose 158
# minimizing fftdock pose 159
# minimizing fftdock pose 160
# minimizing fftdock pose 161
# minimizing fftdock pose 162
# minimizing fftdock pose 163
# minimizing fftdock pose 164
# minimizing fftdock pose 165
# minimizing fftdock pose 166
# minimizing fftdock pose 167
# minimizing fftdock pose 168
# minimizing fftdock pose 169
# minimizing fftdock pose 170
# minimizing fftdock pose 171
# minimizing fftdock pose 172
# minimizing fftdock pose 173
# minimizing fftdock pose 174
# minimizing fftdock pose 175
# minimizing fftdock pose 176
# minimizing fftdock pose 177
# minimizing fftdock pose 178
# minimizing fftdock pose 179
# minimizing fftdock pose 180
# minimizing fftdock pose 181
# minimizing fftdock pose 182
# minimizing fftdock pose 183
# minimizing fftdock pose 184
# minimizing fftdock pose 185
# minimizing fftdock pose 186
# minimizing fftdock pose 187
# minimizing fftdock pose 188
# minimizing fftdock pose 189
# minimizing fftdock pose 190
# minimizing fftdock pose 191
# minimizing fftdock pose 192
# minimizing fftdock pose 193
# minimizing fftdock pose 194
# minimizing fftdock pose 195
# minimizing fftdock pose 196
# minimizing fftdock pose 197
# minimizing fftdock pose 198
# minimizing fftdock pose 199
# minimizing fftdock pose 200
# minimizing fftdock pose 201
# minimizing fftdock pose 202
# minimizing fftdock pose 203
# minimizing fftdock pose 204
# minimizing fftdock pose 205
# minimizing fftdock pose 206
# minimizing fftdock pose 207
# minimizing fftdock pose 208
# minimizing fftdock pose 209
# minimizing fftdock pose 210
# minimizing fftdock pose 211
# minimizing fftdock pose 212
# minimizing fftdock pose 213
# minimizing fftdock pose 214
# minimizing fftdock pose 215
# minimizing fftdock pose 216
# minimizing fftdock pose 217
# minimizing fftdock pose 218
# minimizing fftdock pose 219
# minimizing fftdock pose 220
# minimizing fftdock pose 221
# minimizing fftdock pose 222
# minimizing fftdock pose 223
# minimizing fftdock pose 224
# minimizing fftdock pose 225
# minimizing fftdock pose 226
# minimizing fftdock pose 227
# minimizing fftdock pose 228
# minimizing fftdock pose 229
# minimizing fftdock pose 230
# minimizing fftdock pose 231
# minimizing fftdock pose 232
# minimizing fftdock pose 233
# minimizing fftdock pose 234
# minimizing fftdock pose 235
# minimizing fftdock pose 236
# minimizing fftdock pose 237
# minimizing fftdock pose 238
# minimizing fftdock pose 239
# minimizing fftdock pose 240
# minimizing fftdock pose 241
# minimizing fftdock pose 242
# minimizing fftdock pose 243
# minimizing fftdock pose 244
# minimizing fftdock pose 245
# minimizing fftdock pose 246
# minimizing fftdock pose 247
# minimizing fftdock pose 248
# minimizing fftdock pose 249
# minimizing fftdock pose 250
# minimizing fftdock pose 251
# minimizing fftdock pose 252
# minimizing fftdock pose 253
# minimizing fftdock pose 254
# minimizing fftdock pose 255
# minimizing fftdock pose 256
# minimizing fftdock pose 257
# minimizing fftdock pose 258
# minimizing fftdock pose 259
# minimizing fftdock pose 260
# minimizing fftdock pose 261
# minimizing fftdock pose 262
# minimizing fftdock pose 263
# minimizing fftdock pose 264
# minimizing fftdock pose 265
# minimizing fftdock pose 266
# minimizing fftdock pose 267
# minimizing fftdock pose 268
# minimizing fftdock pose 269
# minimizing fftdock pose 270
# minimizing fftdock pose 271
# minimizing fftdock pose 272
# minimizing fftdock pose 273
# minimizing fftdock pose 274
# minimizing fftdock pose 275
# minimizing fftdock pose 276
# minimizing fftdock pose 277
# minimizing fftdock pose 278
# minimizing fftdock pose 279
# minimizing fftdock pose 280
# minimizing fftdock pose 281
# minimizing fftdock pose 282
# minimizing fftdock pose 283
# minimizing fftdock pose 284
# minimizing fftdock pose 285
# minimizing fftdock pose 286
# minimizing fftdock pose 287
# minimizing fftdock pose 288
# minimizing fftdock pose 289
# minimizing fftdock pose 290
# minimizing fftdock pose 291
# minimizing fftdock pose 292
# minimizing fftdock pose 293
# minimizing fftdock pose 294
# minimizing fftdock pose 295
# minimizing fftdock pose 296
# minimizing fftdock pose 297
# minimizing fftdock pose 298
# minimizing fftdock pose 299
# minimizing fftdock pose 300
# minimizing fftdock pose 301
# minimizing fftdock pose 302
# minimizing fftdock pose 303
# minimizing fftdock pose 304
# minimizing fftdock pose 305
# minimizing fftdock pose 306
# minimizing fftdock pose 307
# minimizing fftdock pose 308
# minimizing fftdock pose 309
# minimizing fftdock pose 310
# minimizing fftdock pose 311
# minimizing fftdock pose 312
# minimizing fftdock pose 313
# minimizing fftdock pose 314
# minimizing fftdock pose 315
# minimizing fftdock pose 316
# minimizing fftdock pose 317
# minimizing fftdock pose 318
# minimizing fftdock pose 319
# minimizing fftdock pose 320
# minimizing fftdock pose 321
# minimizing fftdock pose 322
# minimizing fftdock pose 323
# minimizing fftdock pose 324
# minimizing fftdock pose 325
# minimizing fftdock pose 326
# minimizing fftdock pose 327
# minimizing fftdock pose 328
# minimizing fftdock pose 329
# minimizing fftdock pose 330
# minimizing fftdock pose 331
# minimizing fftdock pose 332
# minimizing fftdock pose 333
# minimizing fftdock pose 334
# minimizing fftdock pose 335
# minimizing fftdock pose 336
# minimizing fftdock pose 337
# minimizing fftdock pose 338
# minimizing fftdock pose 339
# minimizing fftdock pose 340
# minimizing fftdock pose 341
# minimizing fftdock pose 342
# minimizing fftdock pose 343
# minimizing fftdock pose 344
# minimizing fftdock pose 345
# minimizing fftdock pose 346
# minimizing fftdock pose 347
# minimizing fftdock pose 348
# minimizing fftdock pose 349
# minimizing fftdock pose 350
# minimizing fftdock pose 351
# minimizing fftdock pose 352
# minimizing fftdock pose 353
# minimizing fftdock pose 354
# minimizing fftdock pose 355
# minimizing fftdock pose 356
# minimizing fftdock pose 357
# minimizing fftdock pose 358
# minimizing fftdock pose 359
# minimizing fftdock pose 360
# minimizing fftdock pose 361
# minimizing fftdock pose 362
# minimizing fftdock pose 363
# minimizing fftdock pose 364
# minimizing fftdock pose 365
# minimizing fftdock pose 366
# minimizing fftdock pose 367
# minimizing fftdock pose 368
# minimizing fftdock pose 369
# minimizing fftdock pose 370
# minimizing fftdock pose 371
# minimizing fftdock pose 372
# minimizing fftdock pose 373
# minimizing fftdock pose 374
# minimizing fftdock pose 375
# minimizing fftdock pose 376
# minimizing fftdock pose 377
# minimizing fftdock pose 378
# minimizing fftdock pose 379
# minimizing fftdock pose 380
# minimizing fftdock pose 381
# minimizing fftdock pose 382
# minimizing fftdock pose 383
# minimizing fftdock pose 384
# minimizing fftdock pose 385
# minimizing fftdock pose 386
# minimizing fftdock pose 387
# minimizing fftdock pose 388
# minimizing fftdock pose 389
# minimizing fftdock pose 390
# minimizing fftdock pose 391
# minimizing fftdock pose 392
# minimizing fftdock pose 393
# minimizing fftdock pose 394
# minimizing fftdock pose 395
# minimizing fftdock pose 396
# minimizing fftdock pose 397
# minimizing fftdock pose 398
# minimizing fftdock pose 399
# minimizing fftdock pose 400
# minimizing fftdock pose 401
# minimizing fftdock pose 402
# minimizing fftdock pose 403
# minimizing fftdock pose 404
# minimizing fftdock pose 405
# minimizing fftdock pose 406
# minimizing fftdock pose 407
# minimizing fftdock pose 408
# minimizing fftdock pose 409
# minimizing fftdock pose 410
# minimizing fftdock pose 411
# minimizing fftdock pose 412
# minimizing fftdock pose 413
# minimizing fftdock pose 414
# minimizing fftdock pose 415
# minimizing fftdock pose 416
# minimizing fftdock pose 417
# minimizing fftdock pose 418
# minimizing fftdock pose 419
# minimizing fftdock pose 420
# minimizing fftdock pose 421
# minimizing fftdock pose 422
# minimizing fftdock pose 423
# minimizing fftdock pose 424
# minimizing fftdock pose 425
# minimizing fftdock pose 426
# minimizing fftdock pose 427
# minimizing fftdock pose 428
# minimizing fftdock pose 429
# minimizing fftdock pose 430
# minimizing fftdock pose 431
# minimizing fftdock pose 432
# minimizing fftdock pose 433
# minimizing fftdock pose 434
# minimizing fftdock pose 435
# minimizing fftdock pose 436
# minimizing fftdock pose 437
# minimizing fftdock pose 438
# minimizing fftdock pose 439
# minimizing fftdock pose 440
# minimizing fftdock pose 441
# minimizing fftdock pose 442
# minimizing fftdock pose 443
# minimizing fftdock pose 444
# minimizing fftdock pose 445
# minimizing fftdock pose 446
# minimizing fftdock pose 447
# minimizing fftdock pose 448
# minimizing fftdock pose 449
# minimizing fftdock pose 450
# minimizing fftdock pose 451
# minimizing fftdock pose 452
# minimizing fftdock pose 453
# minimizing fftdock pose 454
# minimizing fftdock pose 455
# minimizing fftdock pose 456
# minimizing fftdock pose 457
# minimizing fftdock pose 458
# minimizing fftdock pose 459
# minimizing fftdock pose 460
# minimizing fftdock pose 461
# minimizing fftdock pose 462
# minimizing fftdock pose 463
# minimizing fftdock pose 464
# minimizing fftdock pose 465
# minimizing fftdock pose 466
# minimizing fftdock pose 467
# minimizing fftdock pose 468
# minimizing fftdock pose 469
# minimizing fftdock pose 470
# minimizing fftdock pose 471
# minimizing fftdock pose 472
# minimizing fftdock pose 473
# minimizing fftdock pose 474
# minimizing fftdock pose 475
# minimizing fftdock pose 476
# minimizing fftdock pose 477
# minimizing fftdock pose 478
# minimizing fftdock pose 479
# minimizing fftdock pose 480
# minimizing fftdock pose 481
# minimizing fftdock pose 482
# minimizing fftdock pose 483
# minimizing fftdock pose 484
# minimizing fftdock pose 485
# minimizing fftdock pose 486
# minimizing fftdock pose 487
# minimizing fftdock pose 488
# minimizing fftdock pose 489
# minimizing fftdock pose 490
# minimizing fftdock pose 491
# minimizing fftdock pose 492
# minimizing fftdock pose 493
# minimizing fftdock pose 494
# minimizing fftdock pose 495
# minimizing fftdock pose 496
# minimizing fftdock pose 497
# minimizing fftdock pose 498
# minimizing fftdock pose 499
# minimizing fftdock pose 500
# -2

# %%
#Concat energy dataframes
energy_df = pd.concat(pose_energy_dfs).fillna(0)
energy_df
# Out:
# term        energy        deltae       grms     bonds     angles     ureyb  \
# pose
# initial -14.885048 -1.278977e-13   1.834568  2.273115   3.203081  0.216589
# 1        -1.886479 -1.299857e+01   1.211485  2.349655  16.934136  0.549208
# 2        65.925263 -6.781174e+01   3.086646  4.612438  24.877168  1.239871
# 3        40.865165  2.506010e+01   1.855198  3.131496  23.512255  0.631715
# 4        10.497213  3.036795e+01   1.847578  2.131081   9.631265  0.529235
# ...            ...           ...        ...       ...        ...       ...
# 496      -6.061015  4.395703e+01  10.694298  6.316135  16.101484  0.844611
# 497      22.620147 -2.868116e+01   1.461466  3.536595  10.058342  0.741245
# 498      35.615896 -1.299575e+01   3.558728  3.710906  23.663197  1.236659
# 499       3.979576  3.163632e+01   2.225404  2.267818  16.538047  0.619316
# 500      -8.755040  1.273462e+01   3.699177  3.225442  11.111158  0.391904
#
# term     dihedrals  impropers    vdwaals       elec  hbonds  asp  user
# pose
# initial   6.462700   0.009944  14.654264 -41.704742     0.0  0.0   0.0
# 1        43.922863   0.015866  26.465952 -92.124158     0.0  0.0   0.0
# 2        47.814934   3.716743  73.742378 -90.078269     0.0  0.0   0.0
# 3        60.018098   0.553488  29.889567 -76.871455     0.0  0.0   0.0
# 4        33.382124   0.041067  33.523521 -68.741080     0.0  0.0   0.0
# ...            ...        ...        ...        ...     ...  ...   ...
# 496      20.909595   0.099382  35.514951 -85.847173     0.0  0.0   0.0
# 497      38.886896   0.074635  36.511980 -67.189546     0.0  0.0   0.0
# 498      43.775409   0.065266  52.182042 -89.017583     0.0  0.0   0.0
# 499      49.229269   0.031322  16.565605 -81.271801     0.0  0.0   0.0
# 500      28.462575   0.099351  39.564843 -91.610313     0.0  0.0   0.0
#
# [501 rows x 13 columns]

# %%
#Get final-initial energy
delta_energy_df = energy_df.subtract(energy_df.loc['initial'].values, axis = 1)
delta_energy_df
# Out:
# term        energy     deltae      grms     bonds     angles     ureyb  \
# pose
# initial   0.000000   0.000000  0.000000  0.000000   0.000000  0.000000
# 1        12.998569 -12.998569 -0.623083  0.076540  13.731054  0.332619
# 2        80.810311 -67.811742  1.252078  2.339323  21.674087  1.023282
# 3        55.750213  25.060098  0.020630  0.858381  20.309174  0.415126
# 4        25.382261  30.367952  0.013010 -0.142033   6.428183  0.312646
# ...            ...        ...       ...       ...        ...       ...
# 496       8.824033  43.957035  8.859730  4.043020  12.898402  0.628022
# 497      37.505195 -28.681161 -0.373102  1.263480   6.855261  0.524656
# 498      50.500944 -12.995749  1.724160  1.437791  20.460116  1.020070
# 499      18.864624  31.636321  0.390836 -0.005297  13.334965  0.402727
# 500       6.130008  12.734615  1.864609  0.952328   7.908076  0.175315
#
# term     dihedrals  impropers    vdwaals       elec  hbonds  asp  user
# pose
# initial   0.000000   0.000000   0.000000   0.000000     0.0  0.0   0.0
# 1        37.460163   0.005922  11.811688 -50.419416     0.0  0.0   0.0
# 2        41.352234   3.706799  59.088113 -48.373527     0.0  0.0   0.0
# 3        53.555397   0.543544  15.235303 -35.166713     0.0  0.0   0.0
# 4        26.919424   0.031123  18.869256 -27.036338     0.0  0.0   0.0
# ...            ...        ...        ...        ...     ...  ...   ...
# 496      14.446895   0.089438  20.860686 -44.142431     0.0  0.0   0.0
# 497      32.424195   0.064691  21.857716 -25.484804     0.0  0.0   0.0
# 498      37.312709   0.055322  37.527778 -47.312841     0.0  0.0   0.0
# 499      42.766569   0.021378   1.911341 -39.567059     0.0  0.0   0.0
# 500      21.999875   0.089407  24.910579 -49.905571     0.0  0.0   0.0
#
# [501 rows x 13 columns]

# %%
#Save energies
scorefile = f'scores/{protein}_{ligand}_prot.csv'
delta_energy_df.to_csv(scorefile)
